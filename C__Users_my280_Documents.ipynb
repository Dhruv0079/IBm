# %%
# Exercise 2 - Title of the Notebook
# --------------------------

# Markdown cell for the title
# --------------------------

# Data Science Project Notebook

# Exercise 3 - Introduction
# --------------------------

# Markdown cell for an introduction
# --------------------------

# This Jupyter Notebook is created for the Data Science Project.
# It includes various exercises related to data science concepts.

# Exercise 4 - List Data Science Languages
# --------------------------

# Markdown cell to list data science languages
# --------------------------

# Data Science Languages:
# 1. Python
# 2. R
# 3. Julia

# Exercise 5 - List Data Science Libraries
# --------------------------

# Markdown cell to list data science libraries
# --------------------------

# Data Science Libraries:
# - Pandas
# - NumPy
# - Scikit-Learn
# - Matplotlib
# - Seaborn
# - TensorFlow
# - Keras

# Exercise 6 - Table of Data Science Tools
# --------------------------

# Markdown cell with a table of Data Science tools
# --------------------------

#| Tool               | Description                              |
#|--------------------|------------------------------------------|
#| Jupyter Notebook   | Interactive computing and data analysis  |
#| Anaconda           | Data science platform and distribution   |
#| Tableau            | Data visualization and business analytics|
#| Apache Spark       | Distributed data processing              |
#| SQL               | Relational database querying            |

# Exercise 7 - Introduction to Arithmetic Expression Examples
# --------------------------

# Markdown cell introducing arithmetic expression examples
# --------------------------

# In the following exercises, we'll demonstrate arithmetic expression examples.

# Exercise 8 - Multiply and Add Numbers
# --------------------------

# Code cell to multiply and add numbers
# --------------------------

number1 = 5
number2 = 3

# Multiply two numbers
result_multiply = number1 * number2

# Add two numbers
result_add = number1 + number2

print(f"Multiplication: {number1} * {number2} = {result_multiply}")
print(f"Addition: {number1} + {number2} = {result_add}")

# Exercise 9 - Convert Minutes to Hours
# --------------------------

# Code cell to convert minutes to hours
# --------------------------

minutes = 150

# Calculate hours from minutes
hours = minutes / 60

print(f"{minutes} minutes is equal to {hours} hours.")

# Exercise 10 - List Objectives
# --------------------------

# Markdown cell to list objectives
# --------------------------

# Objectives:
# 1. Explore data science concepts.
# 2. Practice arithmetic expressions.
# 3. Demonstrate the use of Markdown.

# Exercise 11 - Author's Name
# --------------------------

# Markdown cell to indicate the author's name
# --------------------------

# Author: Dhruv
# Exercise 12 - Share Notebook through GitHub
# --------------------------

# Markdown cell to share the notebook through GitHub
# --------------------------

# You can find the complete Jupyter Notebook on my GitHub repository.
# Out:
# Multiplication: 5 * 3 = 15
# Addition: 5 + 3 = 8
# 150 minutes is equal to 2.5 hours.
